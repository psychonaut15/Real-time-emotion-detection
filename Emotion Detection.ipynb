# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\Users\hp\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img = cv2.imread('Happyface.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 predictions = DeepFace.analyze(img)
#
# File ~\anaconda3\Lib\site-packages\deepface\DeepFace.py:329, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     326     models["emotion"] = build_model("Emotion")
#     328 if "age" in actions:
# --> 329     models["age"] = build_model("Age")
#     331 if "gender" in actions:
#     332     models["gender"] = build_model("Gender")
#
# File ~\anaconda3\Lib\site-packages\deepface\DeepFace.py:89, in build_model(model_name)
#      87 model = models.get(model_name)
#      88 if model:
# ---> 89     model = model()
#      90     model_obj[model_name] = model
#      91 else:
#
# File ~\anaconda3\Lib\site-packages\deepface\extendedmodels\Age.py:56, in loadModel(url)
#      53     output = home + "/.deepface/weights/age_model_weights.h5"
#      54     gdown.download(url, output, quiet=False)
# ---> 56 age_model.load_weights(home + "/.deepface/weights/age_model_weights.h5")
#      58 return age_model
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5f.pyx:102, in h5py.h5f.open()
#
# OSError: Unable to synchronously open file (truncated file: eof = 361832280, sblock->base_addr = 0, stored_eof = 538771776)

# %%
predictions

# %%
type(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 type(predictions)
#
# NameError: name 'predictions' is not defined

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           predictions[0]['dominant_emotion'],
           (10,80),
           font, 2,
           (0, 0, 255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('face.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.27it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 7.782438027348348e-08,
#    'disgust': 2.1033097802564546e-16,
#    'fear': 0.010426600783830509,
#    'happy': 2.8901496307298657e-06,
#    'sad': 4.728026780850825e-12,
#    'surprise': 99.9895691871643,
#    'neutral': 4.839199812826304e-15},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 110, 'y': 36, 'w': 84, 'h': 84},
#   'age': 31,
#   'gender': {'Woman': 0.01417062885593623, 'Man': 99.98582601547241},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.00039681581256445497,
#    'indian': 0.0018746781279332936,
#    'black': 2.35639234347218e-05,
#    'white': 97.22378253936768,
#    'middle eastern': 1.780984178185463,
#    'latino hispanic': 0.992937758564949},
#   'dominant_race': 'white'}]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'surprise'
