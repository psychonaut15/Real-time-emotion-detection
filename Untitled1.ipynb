# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('Happyface.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 predictions = DeepFace.analyze(img)
#
# File ~\anaconda3\Lib\site-packages\deepface\DeepFace.py:329, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     326     models["emotion"] = build_model("Emotion")
#     328 if "age" in actions:
# --> 329     models["age"] = build_model("Age")
#     331 if "gender" in actions:
#     332     models["gender"] = build_model("Gender")
#
# File ~\anaconda3\Lib\site-packages\deepface\DeepFace.py:89, in build_model(model_name)
#      87 model = models.get(model_name)
#      88 if model:
# ---> 89     model = model()
#      90     model_obj[model_name] = model
#      91 else:
#
# File ~\anaconda3\Lib\site-packages\deepface\extendedmodels\Age.py:56, in loadModel(url)
#      53     output = home + "/.deepface/weights/age_model_weights.h5"
#      54     gdown.download(url, output, quiet=False)
# ---> 56 age_model.load_weights(home + "/.deepface/weights/age_model_weights.h5")
#      58 return age_model
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (truncated file: eof = 361832280, sblock->base_addr = 0, stored_eof = 538771776)

# %%
type(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 type(predictions)
#
# NameError: name 'predictions' is not defined

# %%
predictions['dominant_emotion']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 predictions['dominant_emotion']
#
# NameError: name 'predictions' is not defined
